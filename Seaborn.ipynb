# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
import matplotlib.pyplot as plt

# %%
tip = sns.load_dataset("tips")

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
 sns.relplot(data=tip,x="total_bill",y="tip",kind = "scatter",hue="sex",style="smoker",size="size")

# %%
gap = px.data.gapminder()

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df = gap[gap["country"]=="India"]

# %%
sns.relplot(data=df,x="year",y="lifeExp",kind="line",hue="")

# %%
df1=gap[gap["country"].isin(["India","Pakistan","China"])]

# %%
sns.relplot(data = df1,x="year",y="lifeExp",hue="country",kind = "line",size = "pop")

# %%
df2=gap[gap["country"].isin(["India","Brazil","Germany"])]

# %%
df2
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
sns.relplot(kind="line",data=df2,x="year",y="lifeExp",hue="country",size="continent")

# %%
sns.relplot(kind="scatter",data=df2,x="year",y="lifeExp",hue="country",size="pop")

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # facet plot by col is for side by side  and row for up and down

# %%
sns.relplot(data=tip,x="total_bill",y="tip",col="sex")

# %%
sns.relplot(data=tip,x="total_bill",y="tip",col ="smoker",row="sex")

# %%
sns.relplot(data=tip,x="total_bill",y="tip",col="day",row="time")

# %%
a=(gap["year"] == 1952)
b=(gap["lifeExp"].max())
gap[a & b]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:315, in na_logical_op(x, y, op)
#     314 try:
# ...

# %%
sns.relplot(data=gap,x="lifeExp",y="gdpPercap",kind="scatter",col = "year",col_wrap=3)

# %%
sns.displot(data=tip,x="total_bill",kind="hist")

# %%
sns.displot(data=tip,x="total_bill",kind="hist",bins=20)

# %%
sns.displot(data=tip,x="tip",kind="hist",hue="day")

# %%
sns.displot(data=tip,x="day",kind="hist",col="time",row="smoker")

# %%
sns.displot(data=tip,x="time",kind="hist")

# %%
sns.relplot(data=tip,x="total_bill",y="tip",kind="scatter",col="day",row="time")

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=tip,x="total_bill",kind="kde",hue="smoker")

# %%
#byverient hist plot
sns.displot(data=tip,x="total_bill",y="tip",kind="hist")

# %%
#byverient kde plot

# %%
sns.displot(data=tip,x="total_bill",y="tip",kind="kde")

# %%
gap.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4

# %%
# need to format year in  wide data to create Heatmap

# %%
temp1 = gap.pivot(index="country",columns="year",values="lifeExp")

# %%
temp1.head()
# Out:
# year           1952    1957    1962    1967    1972    1977    1982    1987  \
# country
# Afghanistan  28.801  30.332  31.997  34.020  36.088  38.438  39.854  40.822
# Albania      55.230  59.280  64.820  66.220  67.690  68.930  70.420  72.000
# Algeria      43.077  45.685  48.303  51.407  54.518  58.014  61.368  65.799
# Angola       30.015  31.999  34.000  35.985  37.928  39.483  39.942  39.906
# Argentina    62.485  64.399  65.142  65.634  67.065  68.481  69.942  70.774
#
# year           1992    1997    2002    2007
# country
# Afghanistan  41.674  41.763  42.129  43.828
# Albania      71.581  72.950  75.651  76.423
# Algeria      67.744  69.152  70.994  72.301
# Angola       40.647  40.963  41.003  42.731
# Argentina    71.868  73.275  74.340  75.320

# %%
plt.figure(figsize=(20,15))
sns.heatmap(temp1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
temp2 = gap.pivot(index="country",columns="year",values="pop")

# %%
temp2
# Out:
# year                    1952      1957      1962      1967      1972  \
# country
# Afghanistan          8425333   9240934  10267083  11537966  13079460
# Albania              1282697   1476505   1728137   1984060   2263554
# Algeria              9279525  10270856  11000948  12760499  14760787
# Angola               4232095   4561361   4826015   5247469   5894858
# Argentina           17876956  19610538  21283783  22934225  24779799
# ...                      ...       ...       ...       ...       ...
# Vietnam             26246839  28998543  33796140  39463910  44655014
# West Bank and Gaza   1030585   1070439   1133134   1142636   1089572
# Yemen, Rep.          4963829   5498090   6120081   6740785   7407075
# Zambia               2672000   3016000   3421000   3900000   4506497
# Zimbabwe             3080907   3646340   4277736   4995432   5861135
#
# year                    1977      1982      1987      1992      1997  \
# country
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(temp2)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
Asian = gap[gap["continent"]=="Asia"].pivot(index="country",columns="year",values="lifeExp")

# %%
Asian.head()
# Out:
# year           1952      1957      1962      1967      1972      1977    1982  \
# country
# Afghanistan  28.801  30.33200  31.99700  34.02000  36.08800  38.43800  39.854
# Bahrain      50.939  53.83200  56.92300  59.92300  63.30000  65.59300  69.052
# Bangladesh   37.484  39.34800  41.21600  43.45300  45.25200  46.92300  50.009
# Cambodia     39.417  41.36600  43.41500  45.41500  40.31700  31.22000  50.957
# China        44.000  50.54896  44.50136  58.38112  63.11888  63.96736  65.525
#
# year           1987    1992    1997    2002    2007
# country
# Afghanistan  40.822  41.674  41.763  42.129  43.828
# Bahrain      70.750  72.601  73.925  74.795  75.635
# Bangladesh   52.819  56.018  59.412  62.013  64.062
# Cambodia     53.914  55.803  56.534  56.752  59.723
# China        67.274  68.690  70.426  72.028  72.961

# %%
plt.figure(figsize=(20,15))
sns.heatmap(Asian,annot=True,cmap="viridis")
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
iris=px.data.iris()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
sns.clustermap(iris.iloc[:,0:3])

# %%
sns.catplot(data=tip,x="day",y="total_bill",kind="strip",hue="sex")

# %%
sns.catplot(data=tip,x="smoker",y="tip",jitter=False)

# %%
#swarmplot

# %%
sns.catplot(data=tip,x="smoker",y="total_bill",kind="swarm",col="day",col_wrap=2)

# %%
sns.boxplot(data=tip,x="sex",y="total_bill")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.catplot(data=tip,x="sex",y="tip",kind="box",col="smoker")

# %% [markdown]
# # we can make box plot on single numerical data

# %%
sns.catplot(data=tip,y="total_bill",kind="box")

# %%
sns.catplot(data=tip,x="sex",y="tip",kind="violin",hue="time")

# %%
sns.barplot(data=tip,x="sex",y="total_bill")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [166], in <cell line: 1>()
# ----> 1 sns.barplot(data=tip,x="sex",y="total_bill",estimator="count")
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:3182, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
# ...

# %%
import numpy as np
sns.catplot(data=tip,x="sex",y="total_bill",kind="bar",hue="smoker",ci=None)

# %%
sns.catplot(data=tip,x="sex",y="total_bill",kind="point",hue="smoker")

# %%
sns.catplot(data=tip,x="sex",kind="count",hue="day")

# %%
sns.regplot(data=tip,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tip,x="total_bill",y="tip",hue="sex")

# %%
#sns.pairplot(iris)
iris.drop(columns="species_id",inplace=True)

# %% [markdown]
# # pair plot build graph on all the available numerical columns in dataframe
# sns.pairplot(iris,hue="species")

# %%
sns.pairplot(iris,hue="species")

# %%
sns.jointplot(data=tip,x="total_bill",y="tip")

# %%
g = sns.JointGrid(data=tip,x="total_bill",y="tip")
g.plot(sns.scatterplot,sns.boxplot)

# %%
g = sns.JointGrid(data=tip,x="total_bill",y="tip",hue="sex")
g.plot(sns.scatterplot,sns.boxplot)
